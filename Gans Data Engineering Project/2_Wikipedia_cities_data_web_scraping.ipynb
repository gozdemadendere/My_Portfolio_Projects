# %% [markdown]
# ## **CITIES DATA**

# %% [markdown]
# # 1) MANUAL WAY

# %%
# colab has an older version of beautifulsoup by default, here we upgrade it
# if you are working on your own computer, you can probably comment this step out and skip it
# !pip install --upgrade beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (4.6.3)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 3.9 MB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.11.2 soupsieve-2.3.2.post1

# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
# create lists
city = []
country = []
area = []
pop = []
lat = []
lon = []

# %% [markdown]
# ### BERLIN

# %%
# find url and store it in a variable
url = "https://en.wikipedia.org/wiki/Berlin"

# %%
# download html with a get request
response = requests.get(url)

# check the HTTP code
response.status_code
# Out:
# 200

# %%
# parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")
soup.title.get_text()
# Out:
# 'Berlin - Wikipedia'

# %%
# let's first try to get the name of the city
# by copying the selector we can see that it has the id firstHeading (it also has a class by the same name!)

# City
soup.select('.mw-page-title-main')[0].get_text()
# Out:
# 'Berlin'

# %%
# Country
soup.select('.infobox-data')[0].get_text()
# Out:
# '\xa0Germany'

# %%
# Area
soup.select('.infobox-data')[6].get_text()
# Out:
# '891.3\xa0km2 (344.1\xa0sq\xa0mi)'

# %%
# Population
soup.select('.infobox-data')[10].get_text()
# Out:
# '3,677,472'

# %%
# Latitude
soup.select(".latitude")[0].get_text()
# Out:
# '52°31′12″N'

# %%
# Longitude
soup.select(".longitude")[0].get_text()
# Out:
# '13°24′18″E'

# %%
for i in range(1):
  city.append(soup.select('.mw-page-title-main')[0].get_text())
  country.append(soup.select('.infobox-data')[0].get_text())
  area.append(soup.select('.infobox-data')[6].get_text())
  pop.append(soup.select('.infobox-data')[10].get_text())
  lat.append(soup.select('.latitude')[0].get_text())
  lon.append(soup.select('.longitude')[0].get_text())

# %% [markdown]
# ### HAMBURG

# %%
# find url and store it in a variable
url = "https://en.wikipedia.org/wiki/Hamburg"

# %%
# download html with a get request
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
# parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")
soup.title.get_text()
# Out:
# 'Hamburg - Wikipedia'

# %%
# City
soup.select('.mw-page-title-main')[0].get_text()
# Out:
# 'Hamburg'

# %%
# Country
soup.select('.infobox-data')[0].get_text()
# Out:
# 'Germany'

# %%
# Area
soup.select('.infobox-data')[7].get_text()
# Out:
# '755.22\xa0km2 (291.59\xa0sq\xa0mi)'

# %%
# Population
soup.select('.infobox-data')[8].get_text()
# Out:
# '1,906,411'

# %%
# Latitude
soup.select(".latitude")[0].get_text()
# Out:
# '53°33′N'

# %%
# Longitude
soup.select(".longitude")[0].get_text()
# Out:
# '10°00′E'

# %%
for i in range(1):
  city.append(soup.select('.mw-page-title-main')[0].get_text())
  country.append(soup.select('.infobox-data')[0].get_text())
  area.append(soup.select('.infobox-data')[7].get_text())
  pop.append(soup.select('.infobox-data')[8].get_text())
  lat.append(soup.select('.latitude')[0].get_text())
  lon.append(soup.select('.longitude')[0].get_text())

# %% [markdown]
# ### LONDON

# %%
# find url and store it in a variable
url = "https://en.wikipedia.org/wiki/London"

# %%
# download html with a get request
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
# parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")
soup.title.get_text()
# Out:
# 'London - Wikipedia'

# %%
# City
soup.select('.mw-page-title-main')[0].get_text()
# Out:
# 'London'

# %%
# Country
soup.select('.infobox-data')[0].get_text()
# Out:
# 'United Kingdom'

# %%
# Area
soup.select('.infobox-data')[10].get_text()
# Out:
# '606.96\xa0sq\xa0mi (1,572.03\xa0km2)'

# %%
# Population
soup.select('.infobox-data')[16].get_text()
# Out:
# '8,799,800[1]'

# %%
# Latitude
soup.select(".latitude")[0].get_text()
# Out:
# '51°30′26″N'

# %%
# Longitude
soup.select(".longitude")[0].get_text()
# Out:
# '0°7′39″W'

# %%
for i in range(1):
  city.append(soup.select('.mw-page-title-main')[0].get_text())
  country.append(soup.select('.infobox-data')[0].get_text())
  area.append(soup.select('.infobox-data')[10].get_text())
  pop.append(soup.select('.infobox-data')[16].get_text())
  lat.append(soup.select('.latitude')[0].get_text())
  lon.append(soup.select('.longitude')[0].get_text())

# %% [markdown]
# ### ISTANBUL

# %%
# find url and store it in a variable
url = "https://en.wikipedia.org/wiki/Istanbul"

# %%
# download html with a get request
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
# parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")
soup.title.get_text()
# Out:
# 'Istanbul - Wikipedia'

# %%
# City
soup.select('.mw-page-title-main')[0].get_text()
# Out:
# 'Istanbul'

# %%
# Country
soup.select('.infobox-data')[0].get_text()
# Out:
# '\xa0Turkey'

# %%
# Area
soup.select('.infobox-data')[9].get_text()
# Out:
# '2,576.85\xa0km2 (994.93\xa0sq\xa0mi)'

# %%
# Population
soup.select('.infobox-data')[12].get_text()
# Out:
# '15,907,951'

# %%
# Latitude
soup.select(".latitude")[0].get_text()
# Out:
# '41°00′49″N'

# %%
# Longitude
soup.select(".longitude")[0].get_text()
# Out:
# '28°57′18″E'

# %%
for i in range(1):
  city.append(soup.select('.mw-page-title-main')[0].get_text())
  country.append(soup.select('.infobox-data')[0].get_text())
  area.append(soup.select('.infobox-data')[9].get_text())
  pop.append(soup.select('.infobox-data')[12].get_text())
  lat.append(soup.select('.latitude')[0].get_text())
  lon.append(soup.select('.longitude')[0].get_text())

# %% [markdown]
# ### BARCELONA

# %%
# find url and store it in a variable
url = "https://en.wikipedia.org/wiki/Barcelona"

# %%
# download html with a get request
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
# parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")
soup.title.get_text()
# Out:
# 'Barcelona - Wikipedia'

# %%
# City
soup.select('.mw-page-title-main')[0].get_text()
# Out:
# 'Barcelona'

# %%
# Country
soup.select('.infobox-data')[0].get_text()
# Out:
# '\xa0Spain'

# %%
# Area
soup.select('.infobox-data')[8].get_text()
# Out:
# '101.4\xa0km2 (39.2\xa0sq\xa0mi)'

# %%
# Population
soup.select('.infobox-data')[10].get_text()
# Out:
# '1,620,343'

# %%
# Latitude
soup.select(".latitude")[0].get_text()
# Out:
# '41°23′N'

# %%
# Longitude
soup.select(".longitude")[0].get_text()
# Out:
# '2°11′E'

# %%
for i in range(1):
  city.append(soup.select('.mw-page-title-main')[0].get_text())
  country.append(soup.select('.infobox-data')[0].get_text())
  area.append(soup.select('.infobox-data')[8].get_text())
  pop.append(soup.select('.infobox-data')[10].get_text())
  lat.append(soup.select('.latitude')[0].get_text())
  lon.append(soup.select('.longitude')[0].get_text())

# %% [markdown]
# ## CITIES DATAFRAME

# %%
cities_df = pd.DataFrame(
    {'city': city,
     'country': country,
     'area': area,
     'population': pop,
     'latitude': lat,
     'longitude': lon}
)
cities_df
# Out:
#         city         country                         area    population  \
# 0     Berlin         Germany      891.3 km2 (344.1 sq mi)     3,677,472
# 1    Hamburg         Germany    755.22 km2 (291.59 sq mi)     1,906,411
# 2     London  United Kingdom  606.96 sq mi (1,572.03 km2)  8,799,800[1]
# 3   Istanbul          Turkey  2,576.85 km2 (994.93 sq mi)    15,907,951
# 4  Barcelona           Spain       101.4 km2 (39.2 sq mi)     1,620,343
#
#      latitude   longitude
# 0  52°31′12″N  13°24′18″E
# 1     53°33′N     10°00′E
# 2  51°30′26″N    0°7′39″W
# 3  41°00′49″N  28°57′18″E
# 4     41°23′N      2°11′E

# %% [markdown]
# # 2) FUNCTIONAL WAY

# %%
# colab has an older version of beautifulsoup by default, here we upgrade it
# if you are working on your own computer, you can probably comment this step out and skip it
# !pip install --upgrade beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.8/dist-packages (from beautifulsoup4) (2.3.2.post1)

# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %%
def function(cities):
  # empty list
  list_for_df = []
  
  # begin a for loop to create a dictionary of information for each city
  for city in cities:
    url = f'https://en.wikipedia.org/wiki/{city}'

    # here we make our soup for the city
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')

    # here we initialise our empty dictionary for the city
    response_dict = {}

    # here we fill the dictionary with information using the ids, classes, and selectors that we found in the html
    response_dict['city'] = soup.select(".firstHeading")[0].get_text()
    response_dict['country'] = soup.select(".infobox-data")[0].get_text()
    response_dict['latitude'] = soup.select(".latitude")[0].get_text()
    response_dict['longitude'] = soup.select(".longitude")[0].get_text()
    
    # not all of the wikipedia pages contain elevation, look at Hamburg
    # the if clause means that our code can continue and won't stop at this hurdle
    if soup.select_one('.infobox-label:-soup-contains("Elevation")'):
      response_dict['elevation'] = soup.select_one('.infobox-label:-soup-contains("Elevation")').find_next(class_='infobox-data').get_text()
    response_dict['website'] = soup.select_one('.infobox-label:-soup-contains("Website")').find_next(class_='infobox-data').get_text()
    if soup.select_one('th.infobox-header:-soup-contains("Population")'):
        response_dict['population'] = soup.select_one('th.infobox-header:-soup-contains("Population")').parent.find_next_sibling().find(text=re.compile(r'\d+'))
    
    # add our dictionary for the city to list_for_df
    list_for_df.append(response_dict)
  
  # make the DataFrame
  cities_df = pd.DataFrame(list_for_df)

  # fixing latitude
  cities_df['latitude'] = cities_df['latitude'].str.split('″').str[0].str.replace('°', '.', regex=False).str.replace('′', '', regex=False)
  # fixing longitude
  cities_df['longitude'] = cities_df['longitude'].str.split('″').str[0].str.replace('°', '.', regex=False).str.replace('′', '', regex=False)
  # fixing elevation
  cities_df.insert(4, 'elevation_in_meters', cities_df['elevation'].str.split('m').str[0].str.strip())

  # return the DataFrame
  return cities_df

# %% [markdown]
# ## CITIES DATAFRAME

# %%
list_of_cities = ['Berlin', 'Hamburg', 'London', 'Istanbul', 'Barcelona']
cities_df = function(list_of_cities)

cities_df
# Out:
# <ipython-input-57-60652f7afd8a>:28: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   response_dict['population'] = soup.select_one('th.infobox-header:-soup-contains("Population")').parent.find_next_sibling().find(text=re.compile(r'\d+'))
#         city         country latitude longitude elevation_in_meters  \
# 0     Berlin         Germany  52.3112   13.2418                  34
# 1    Hamburg         Germany   53.33N    10.00E                 NaN
# 2     London  United Kingdom  51.3026     0.739           36 ft (11
# 3   Istanbul          Turkey  41.0049   28.5718                 NaN
# 4  Barcelona           Spain   41.23N     2.11E                  12
#
#        elevation                                            website  \
# 0  34 m (112 ft)                                          berlin.de
# 1            NaN                       www.hamburg.de/stadt-staat/
# 2   36 ft (11 m)                                 www.london.gov.uk
# 3            NaN  ibb.istanbul (in Turkish)www.istanbul.gov.tr (...
# 4   12 m (39 ft)                                 www.barcelona.cat
#
#    population
# 0   3,677,472
# 1   1,906,411
# 2   8,799,800
# 3  15,907,951
# 4   1,620,343

# %% [markdown]
# # 3) SAVE DATAFRAME

# %%
from google.colab import files

cities_df.to_csv("cities_df.csv", index=False)
files.download("cities_df.csv")
