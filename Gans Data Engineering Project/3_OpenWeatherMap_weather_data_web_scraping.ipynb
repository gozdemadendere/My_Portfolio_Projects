# %% [markdown]
# # **WEATHER DATA**

# %% [markdown]
# ## 1) MANUAL WAY

# %%
# import libraries
import pandas as pd
import requests
from datetime import datetime
import pytz

# %%
city = 'Berlin'

# %%
# my API
API_key = "d33337dea54eb73898dd268ae77230f3"

url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric")

# use url > make a request > download html  https://openweathermap.org/forecast5
response = requests.get(url)

# format scraped data into JSON format
response = response.json()

response
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1676030400,
#    'main': {'temp': 4.47,
#     'feels_like': 0.83,
#     'temp_min': 4.47,
#     'temp_max': 4.7,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1028,
#     'humidity': 81,
#     'temp_kf': -0.23},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 4.69, 'deg': 261, 'gust': 8.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-10 12:00:00'},
#   {'dt': 1676041200,
#    'main': {'temp': 4.48,
#     'feels_like': 1.18,
#     'temp_min': 4.48,
#     'temp_max': 4.5,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1027,
#     'humidity': 79,
#     'temp_kf': -0.02},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 4.07, 'deg': 249, 'gust': 8.85},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-10 15:00:00'},
#   {'dt': 1676052000,
#    'main': {'temp': 2.91,
#     'feels_like': -0.93,
#     'temp_min': 2.13,
#     'temp_max': 2.91,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1027,
#     'humidity': 83,
#     'temp_kf': 0.78},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 4.36, 'deg': 239, 'gust': 12.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-10 18:00:00'},
#   {'dt': 1676062800,
#    'main': {'temp': 1.6,
#     'feels_like': -2.96,
#     'temp_min': 1.6,
#     'temp_max': 1.6,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1026,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 5.08, 'deg': 234, 'gust': 13.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-10 21:00:00'},
#   {'dt': 1676073600,
#    'main': {'temp': 2.33,
#     'feels_like': -2.28,
#     'temp_min': 2.33,
#     'temp_max': 2.33,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1024,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 5.54, 'deg': 243, 'gust': 15.15},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-11 00:00:00'},
#   {'dt': 1676084400,
#    'main': {'temp': 3.08,
#     'feels_like': -1.28,
#     'temp_min': 3.08,
#     'temp_max': 3.08,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1022,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.44, 'deg': 252, 'gust': 14.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-11 03:00:00'},
#   {'dt': 1676095200,
#    'main': {'temp': 3.58,
#     'feels_like': -0.67,
#     'temp_min': 3.58,
#     'temp_max': 3.58,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1022,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.48, 'deg': 252, 'gust': 13.88},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-11 06:00:00'},
#   {'dt': 1676106000,
#    'main': {'temp': 4.24,
#     'feels_like': -0.02,
#     'temp_min': 4.24,
#     'temp_max': 4.24,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1022,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.89, 'deg': 259, 'gust': 14.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-11 09:00:00'},
#   {'dt': 1676116800,
#    'main': {'temp': 5.46,
#     'feels_like': 1.37,
#     'temp_min': 5.46,
#     'temp_max': 5.46,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1022,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.29, 'deg': 266, 'gust': 14.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-11 12:00:00'},
#   {'dt': 1676127600,
#    'main': {'temp': 6.57,
#     'feels_like': 2.72,
#     'temp_min': 6.57,
#     'temp_max': 6.57,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1022,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.45, 'deg': 284, 'gust': 13},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-11 15:00:00'},
#   {'dt': 1676138400,
#    'main': {'temp': 6.59,
#     'feels_like': 3.17,
#     'temp_min': 6.59,
#     'temp_max': 6.59,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1024,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.36, 'deg': 281, 'gust': 13.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-11 18:00:00'},
#   {'dt': 1676149200,
#    'main': {'temp': 6.7,
#     'feels_like': 3.92,
#     'temp_min': 6.7,
#     'temp_max': 6.7,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1026,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 4.06, 'deg': 291, 'gust': 10.66},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-11 21:00:00'},
#   {'dt': 1676160000,
#    'main': {'temp': 6.13,
#     'feels_like': 4.07,
#     'temp_min': 6.13,
#     'temp_max': 6.13,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1027,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 2.72, 'deg': 280, 'gust': 7.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-12 00:00:00'},
#   {'dt': 1676170800,
#    'main': {'temp': 6.44,
#     'feels_like': 3.92,
#     'temp_min': 6.44,
#     'temp_max': 6.44,
#     'pressure': 1033,
#     'sea_level': 1033,
#     'grnd_level': 1027,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.49, 'deg': 283, 'gust': 9.36},
#    'visibility': 9683,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-12 03:00:00'},
#   {'dt': 1676181600,
#    'main': {'temp': 6.46,
#     'feels_like': 3.76,
#     'temp_min': 6.46,
#     'temp_max': 6.46,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1029,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.81, 'deg': 294, 'gust': 8.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-12 06:00:00'},
#   {'dt': 1676192400,
#    'main': {'temp': 7.42,
#     'feels_like': 4.8,
#     'temp_min': 7.42,
#     'temp_max': 7.42,
#     'pressure': 1036,
#     'sea_level': 1036,
#     'grnd_level': 1030,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.07, 'deg': 297, 'gust': 7.68},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-12 09:00:00'},
#   {'dt': 1676203200,
#    'main': {'temp': 9.67,
#     'feels_like': 7.46,
#     'temp_min': 9.67,
#     'temp_max': 9.67,
#     'pressure': 1035,
#     'sea_level': 1035,
#     'grnd_level': 1030,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 4.3, 'deg': 288, 'gust': 6.95},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-12 12:00:00'},
#   {'dt': 1676214000,
#    'main': {'temp': 9.68,
#     'feels_like': 7.81,
#     'temp_min': 9.68,
#     'temp_max': 9.68,
#     'pressure': 1035,
#     'sea_level': 1035,
#     'grnd_level': 1030,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 37},
#    'wind': {'speed': 3.58, 'deg': 288, 'gust': 7.08},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-12 15:00:00'},
#   {'dt': 1676224800,
#    'main': {'temp': 6.56,
#     'feels_like': 4.83,
#     'temp_min': 6.56,
#     'temp_max': 6.56,
#     'pressure': 1036,
#     'sea_level': 1036,
#     'grnd_level': 1031,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 27},
#    'wind': {'speed': 2.4, 'deg': 272, 'gust': 5.72},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-12 18:00:00'},
#   {'dt': 1676235600,
#    'main': {'temp': 5.24,
#     'feels_like': 3.26,
#     'temp_min': 5.24,
#     'temp_max': 5.24,
#     'pressure': 1036,
#     'sea_level': 1036,
#     'grnd_level': 1031,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 77},
#    'wind': {'speed': 2.41, 'deg': 266, 'gust': 5.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-12 21:00:00'},
#   {'dt': 1676246400,
#    'main': {'temp': 4.22,
#     'feels_like': 2,
#     'temp_min': 4.22,
#     'temp_max': 4.22,
#     'pressure': 1036,
#     'sea_level': 1036,
#     'grnd_level': 1031,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 2.47, 'deg': 257, 'gust': 6.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-13 00:00:00'},
#   {'dt': 1676257200,
#    'main': {'temp': 3.37,
#     'feels_like': 1.02,
#     'temp_min': 3.37,
#     'temp_max': 3.37,
#     'pressure': 1036,
#     'sea_level': 1036,
#     'grnd_level': 1030,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 70},
#    'wind': {'speed': 2.44, 'deg': 258, 'gust': 6.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-13 03:00:00'},
#   {'dt': 1676268000,
#    'main': {'temp': 2.78,
#     'feels_like': 0.41,
#     'temp_min': 2.78,
#     'temp_max': 2.78,
#     'pressure': 1035,
#     'sea_level': 1035,
#     'grnd_level': 1030,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 53},
#    'wind': {'speed': 2.35, 'deg': 263, 'gust': 6.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-13 06:00:00'},
#   {'dt': 1676278800,
#    'main': {'temp': 5.28,
#     'feels_like': 2.95,
#     'temp_min': 5.28,
#     'temp_max': 5.28,
#     'pressure': 1036,
#     'sea_level': 1036,
#     'grnd_level': 1030,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 13},
#    'wind': {'speed': 2.85, 'deg': 269, 'gust': 5.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-13 09:00:00'},
#   {'dt': 1676289600,
#    'main': {'temp': 8.85,
#     'feels_like': 6.8,
#     'temp_min': 8.85,
#     'temp_max': 8.85,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1029,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 3.58, 'deg': 278, 'gust': 5.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-13 12:00:00'},
#   {'dt': 1676300400,
#    'main': {'temp': 8.99,
#     'feels_like': 7.35,
#     'temp_min': 8.99,
#     'temp_max': 8.99,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1028,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 2.91, 'deg': 284, 'gust': 5.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-13 15:00:00'},
#   {'dt': 1676311200,
#    'main': {'temp': 5.8,
#     'feels_like': 3.94,
#     'temp_min': 5.8,
#     'temp_max': 5.8,
#     'pressure': 1033,
#     'sea_level': 1033,
#     'grnd_level': 1028,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 2.39, 'deg': 285, 'gust': 5.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-13 18:00:00'},
#   {'dt': 1676322000,
#    'main': {'temp': 4.42,
#     'feels_like': 2.5,
#     'temp_min': 4.42,
#     'temp_max': 4.42,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1028,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.19, 'deg': 289, 'gust': 3.74},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-13 21:00:00'},
#   {'dt': 1676332800,
#    'main': {'temp': 3.49,
#     'feels_like': 1.7,
#     'temp_min': 3.49,
#     'temp_max': 3.49,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1029,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.92, 'deg': 302, 'gust': 2.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-14 00:00:00'},
#   {'dt': 1676343600,
#    'main': {'temp': 2.83,
#     'feels_like': 0.91,
#     'temp_min': 2.83,
#     'temp_max': 2.83,
#     'pressure': 1033,
#     'sea_level': 1033,
#     'grnd_level': 1028,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.94, 'deg': 296, 'gust': 2.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-14 03:00:00'},
#   {'dt': 1676354400,
#    'main': {'temp': 2.32,
#     'feels_like': 2.32,
#     'temp_min': 2.32,
#     'temp_max': 2.32,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1028,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 0.91, 'deg': 314, 'gust': 0.9},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-14 06:00:00'},
#   {'dt': 1676365200,
#    'main': {'temp': 5.15,
#     'feels_like': 5.15,
#     'temp_min': 5.15,
#     'temp_max': 5.15,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1028,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 0.44, 'deg': 19, 'gust': 0.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-14 09:00:00'},
#   {'dt': 1676376000,
#    'main': {'temp': 8.48,
#     'feels_like': 8.48,
#     'temp_min': 8.48,
#     'temp_max': 8.48,
#     'pressure': 1033,
#     'sea_level': 1033,
#     'grnd_level': 1028,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 1.01, 'deg': 102, 'gust': 1.3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-14 12:00:00'},
#   {'dt': 1676386800,
#    'main': {'temp': 8.82,
#     'feels_like': 8.38,
#     'temp_min': 8.82,
#     'temp_max': 8.82,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1027,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 1.43, 'deg': 106, 'gust': 2.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-14 15:00:00'},
#   {'dt': 1676397600,
#    'main': {'temp': 5.7,
#     'feels_like': 3.85,
#     'temp_min': 5.7,
#     'temp_max': 5.7,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1026,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 2.36, 'deg': 120, 'gust': 3.9},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-14 18:00:00'},
#   {'dt': 1676408400,
#    'main': {'temp': 4.17,
#     'feels_like': 2.03,
#     'temp_min': 4.17,
#     'temp_max': 4.17,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1025,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 2.38, 'deg': 125, 'gust': 4.74},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-14 21:00:00'},
#   {'dt': 1676419200,
#    'main': {'temp': 3.15,
#     'feels_like': 0.72,
#     'temp_min': 3.15,
#     'temp_max': 3.15,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1024,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 2.49, 'deg': 122, 'gust': 6.1},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-15 00:00:00'},
#   {'dt': 1676430000,
#    'main': {'temp': 2.52,
#     'feels_like': -0.42,
#     'temp_min': 2.52,
#     'temp_max': 2.52,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1023,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.94, 'deg': 115, 'gust': 8.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-15 03:00:00'},
#   {'dt': 1676440800,
#    'main': {'temp': 2.13,
#     'feels_like': -1.3,
#     'temp_min': 2.13,
#     'temp_max': 2.13,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1022,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.47, 'deg': 119, 'gust': 10.3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-02-15 06:00:00'},
#   {'dt': 1676451600,
#    'main': {'temp': 5.07,
#     'feels_like': 1.95,
#     'temp_min': 5.07,
#     'temp_max': 5.07,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1022,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4, 'deg': 129, 'gust': 9.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-02-15 09:00:00'}],
#  'city': {'id': 2950159,
#   'name': 'Berlin',
#   'coord': {'lat': 52.5244, 'lon': 13.4105},
#   'country': 'DE',
#   'population': 1000000,
#   'timezone': 3600,
#   'sunrise': 1676010799,
#   'sunset': 1676045279}}

# %% [markdown]
# Let's get a timestamp of when we get the data. Datetime uses the uses the current time of the system, which on local computers is normally correct. But as we're in the cloud, computers are not always in our country, and we therefore add on the timezone module to ensure that our timestamp is local to us and not the computer.

# %%
tz = pytz.timezone('Europe/Berlin')
now = datetime.now().astimezone(tz)

now
# Out:
# datetime.datetime(2023, 2, 10, 12, 5, 13, 456477, tzinfo=<DstTzInfo 'Europe/Berlin' CET+1:00:00 STD>)

# %%
# we'll store the information in this dicitonary:
weather_dict = {'city': [],
                'country': [],
                'forecast_time': [],
                'outlook': [],
                'detailed_outlook': [],
                'temperature': [],
                'temperature_feels_like': [],
                'clouds': [],
                'rain': [],
                'snow': [],
                'wind_speed': [],
                'wind_deg': [],
                'humidity': [],
                'pressure': []}

# %%
# let's begin the loop
for i in response['list']:
  weather_dict['city'].append(response['city']['name'])
  weather_dict['country'].append(response['city']['country'])
  weather_dict['forecast_time'].append(i['dt_txt'])
  weather_dict['outlook'].append(i['weather'][0]['main'])
  weather_dict['detailed_outlook'].append(i['weather'][0]['description'])
  weather_dict['temperature'].append(i['main']['temp'])
  weather_dict['temperature_feels_like'].append(i['main']['feels_like'])
  weather_dict['clouds'].append(i['clouds']['all'])
  # sometimes the data is missing for rain and snow. As it is not always raining or snowing
  # we cannot make a DataFrame unless the lists are all the same length, therefore missing values are bad
  # here we say try to append a value if there is one. If not, append a 0
  try:
      weather_dict['rain'].append(i['rain']['3h'])
  except:
      weather_dict['rain'].append('0')
  try:
      weather_dict['snow'].append(i['snow']['3h'])
  except:
      weather_dict['snow'].append('0')
  weather_dict['wind_speed'].append(i['wind']['speed'])
  weather_dict['wind_deg'].append(i['wind']['deg'])
  weather_dict['humidity'].append(i['main']['humidity'])
  weather_dict['pressure'].append(i['main']['pressure'])
  #weather_dict['information_retrieved_at'].append(now.strftime("%d/%m/%Y %H:%M:%S"))

# %% [markdown]
# **Now** we convert our dictionary to a DataFrame

# %%
weather_from_dict_df = pd.DataFrame(weather_dict)

weather_from_dict_df.head()
# Out:
#      city country        forecast_time outlook detailed_outlook  temperature  \
# 0  Berlin      DE  2023-02-10 12:00:00  Clouds    broken clouds         4.47
# 1  Berlin      DE  2023-02-10 15:00:00  Clouds    broken clouds         4.48
# 2  Berlin      DE  2023-02-10 18:00:00  Clouds  overcast clouds         2.91
# 3  Berlin      DE  2023-02-10 21:00:00  Clouds    broken clouds         1.60
# 4  Berlin      DE  2023-02-11 00:00:00  Clouds  overcast clouds         2.33
#
#    temperature_feels_like  clouds rain snow  wind_speed  wind_deg  humidity  \
# 0                    0.83      75    0    0        4.69       261        81
# 1                    1.18      83    0    0        4.07       249        79
# 2                   -0.93      90    0    0        4.36       239        83
# 3                   -2.96      81    0    0        5.08       234        79
# 4                   -2.28      90    0    0        5.54       243        81
#
#    pressure
# 0      1024
# 1      1027
# 2      1030
# 3      1032
# 4      1030

# %% [markdown]
# ## 2) FUNCTIONAL WAY

# %% [markdown]
# **As a final step**, to keep everything tidy: let's bring everything we did together in a function. And allow the function to take a list of cities as an input

# %%
# import libraries
import pandas as pd
import requests
from datetime import datetime
import pytz

# %%
def function(cities):
  API_key = "d33337dea54eb73898dd268ae77230f3"

  tz = pytz.timezone('Europe/Berlin')
  now = datetime.now().astimezone(tz)

  weather_dict = {'city': [],
                'country': [],
                'forecast_time': [],
                'outlook': [],
                'detailed_outlook': [],
                'temperature': [],
                'temperature_feels_like': [],
                'clouds': [],
                'rain': [],
                'snow': [],
                'wind_speed': [],
                'wind_deg': [],
                'humidity': [],
                'pressure': [],
                'information_retrieved_at': []}

  for city in cities:
    url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric")
    
    # use url > make a request > download html  https://openweathermap.org/forecast5
    response = requests.get(url)

    # format scraped data into JSON format
    response = response.json()

    for i in response['list']:
      weather_dict['city'].append(response['city']['name'])
      weather_dict['country'].append(response['city']['country'])
      weather_dict['forecast_time'].append(i['dt_txt'])
      weather_dict['outlook'].append(i['weather'][0]['main'])
      weather_dict['detailed_outlook'].append(i['weather'][0]['description'])
      weather_dict['temperature'].append(i['main']['temp'])
      weather_dict['temperature_feels_like'].append(i['main']['feels_like'])
      weather_dict['clouds'].append(i['clouds']['all'])
      try:
          weather_dict['rain'].append(i['rain']['3h'])
      except:
          weather_dict['rain'].append('0')
      try:
          weather_dict['snow'].append(i['snow']['3h'])
      except:
          weather_dict['snow'].append('0')
      weather_dict['wind_speed'].append(i['wind']['speed'])
      weather_dict['wind_deg'].append(i['wind']['deg'])
      weather_dict['humidity'].append(i['main']['humidity'])
      weather_dict['pressure'].append(i['main']['pressure'])
      weather_dict['information_retrieved_at'].append(now.strftime("%d/%m/%Y %H:%M:%S"))

  return pd.DataFrame(weather_dict)

# %% [markdown]
# ### WEATHER DATAFRAME

# %%
list_of_cities = ['Berlin', 'Hamburg', 'London', 'Istanbul', 'Barcelona']

# use the function
weather_df = function(list_of_cities)
weather_df
# Out:
#           city country        forecast_time outlook  detailed_outlook  \
# 0       Berlin      DE  2023-02-10 12:00:00  Clouds     broken clouds
# 1       Berlin      DE  2023-02-10 15:00:00  Clouds     broken clouds
# 2       Berlin      DE  2023-02-10 18:00:00  Clouds   overcast clouds
# 3       Berlin      DE  2023-02-10 21:00:00  Clouds     broken clouds
# 4       Berlin      DE  2023-02-11 00:00:00  Clouds   overcast clouds
# ..         ...     ...                  ...     ...               ...
# 195  Barcelona      ES  2023-02-14 21:00:00  Clouds        few clouds
# 196  Barcelona      ES  2023-02-15 00:00:00  Clouds  scattered clouds
# 197  Barcelona      ES  2023-02-15 03:00:00  Clouds        few clouds
# 198  Barcelona      ES  2023-02-15 06:00:00  Clouds        few clouds
# 199  Barcelona      ES  2023-02-15 09:00:00  Clouds     broken clouds
#
#      temperature  temperature_feels_like  clouds rain snow  wind_speed  \
# 0           4.47                    0.83      75    0    0        4.69
# 1           4.48                    1.18      83    0    0        4.07
# 2           2.91                   -0.93      90    0    0        4.36
# 3           1.60                   -2.96      81    0    0        5.08
# 4           2.33                   -2.28      90    0    0        5.54
# ..           ...                     ...     ...  ...  ...         ...
# 195        10.51                    9.71      17    0    0        0.24
# 196         9.68                    9.34      30    0    0        1.45
# 197         8.99                    8.10      16    0    0        1.90
# 198         8.75                    7.49      18    0    0        2.30
# 199        10.57                    9.56      74    0    0        2.21
#
#      wind_deg  humidity  pressure information_retrieved_at
# 0         261        81      1024      10/02/2023 12:05:13
# 1         249        79      1027      10/02/2023 12:05:13
# 2         239        83      1030      10/02/2023 12:05:13
# 3         234        79      1032      10/02/2023 12:05:13
# 4         243        81      1030      10/02/2023 12:05:13
# ..        ...       ...       ...                      ...
# 195        82        80      1028      10/02/2023 12:05:13
# 196       345        83      1026      10/02/2023 12:05:13
# 197        12        81      1025      10/02/2023 12:05:13
# 198        21        75      1024      10/02/2023 12:05:13
# 199        59        72      1023      10/02/2023 12:05:13
#
# [200 rows x 15 columns]

# %% [markdown]
# # 3) SAVE DATAFRAME

# %%
from google.colab import files

weather_df.to_csv("weather_df.csv", index=False)
files.download("weather_df.csv")
